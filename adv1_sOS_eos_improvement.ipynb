# %% [markdown]
# <a href="https://colab.research.google.com/github/pablex72/research-camp-time-ser/blob/main/adv1_sOS_eos_improvement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Good one perso siN EOS NI SOS

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# Data
# (Same data as provided in the previous example)
# Data
dates = ["3/22/2019", "3/27/2019", "4/1/2019", "4/6/2019", "4/11/2019", "4/16/2019", "4/21/2019", "4/26/2019",
         "5/1/2019", "5/6/2019", "5/11/2019", "5/16/2019", "5/21/2019", "5/26/2019", "5/31/2019", "6/5/2019",
         "6/10/2019", "6/15/2019", "6/20/2019", "6/25/2019", "6/30/2019", "7/5/2019", "7/10/2019", "7/15/2019",
         "7/20/2019", "7/25/2019", "7/30/2019", "8/4/2019", "8/9/2019", "8/14/2019", "8/19/2019", "8/24/2019",
         "8/29/2019", "9/3/2019", "9/8/2019", "9/13/2019", "9/18/2019", "9/23/2019", "9/28/2019"]
values = [0.281380591, 0.287602726, 0.299299509, 0.31441601, 0.331162388, 0.348809159, 0.366891929, 0.384946305,
          0.40245252, 0.418669328, 0.43280011, 0.44404825, 0.451617129, 0.45471013, 0.452530635, 0.444282026,
          0.429602879, 0.409872548, 0.386774254, 0.36146592, 0.334974142, 0.308250355, 0.281945353, 0.256634769,
          0.232894234, 0.211299383, 0.192425846, 0.17669418, 0.163904626, 0.153702351, 0.145732521, 0.139640299,
          0.135070852, 0.131669344, 0.129080942, 0.12695081, 0.125007236, 0.123310994, 0.122005983]
# Convert dates to days since the first date
date_format = "%m/%d/%Y"
days_since_start = [(datetime.strptime(date, date_format) - datetime.strptime(dates[0], date_format)).days for date in dates]

# Calculate the seven phenology-related metrics
base = (min(values[:len(values) // 2]) + min(values[len(values) // 2:])) / 2
maximum = max(values)
amplitude = maximum - base
large_integral = np.trapz(values, dx=1)
small_integral = np.trapz([base] * len(values), dx=1)

# Print the calculated metrics
print("Base:", base)
print("Maximum:", maximum)
print("Amplitude:", amplitude)

print("Large Integral:", large_integral)
print("Small Integral:", small_integral)

# Create a plot highlighting the parameters
# Calculate days since the first date for each date in the list
date_values = [datetime.strptime(date, date_format) for date in dates]
days_since_start_list = [(date - date_values[0]).days for date in date_values]

# Create a plot highlighting the parameters
plt.figure(figsize=(10, 6))
plt.plot(dates, values, label="NDVI", marker='o', color='blue')
plt.axhline(y=base, color='red', linestyle='--', label="Base")
plt.axhline(y=maximum, color='green', linestyle='--', label="Maximum")
plt.fill_between(dates, base, values, where=[False if v < base else True for v in values], alpha=0.2, color='purple', label="Amplitude Area")

plt.xlabel("Date")
plt.ylabel("NDVI")
plt.title("NDVI Time Series with Phenology Metrics")
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# Base: 0.201693287
# Maximum: 0.45471013
# Amplitude: 0.253016843
# Large Integral: 10.992835279
# Small Integral: 7.664344906000002

# %% [markdown]
# #good to visualezo

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# Data
# (Same data as provided in the previous example)
# Data
dates = ["3/22/2019", "3/27/2019", "4/1/2019", "4/6/2019", "4/11/2019", "4/16/2019", "4/21/2019", "4/26/2019",
         "5/1/2019", "5/6/2019", "5/11/2019", "5/16/2019", "5/21/2019", "5/26/2019", "5/31/2019", "6/5/2019",
         "6/10/2019", "6/15/2019", "6/20/2019", "6/25/2019", "6/30/2019", "7/5/2019", "7/10/2019", "7/15/2019",
         "7/20/2019", "7/25/2019", "7/30/2019", "8/4/2019", "8/9/2019", "8/14/2019", "8/19/2019", "8/24/2019",
         "8/29/2019", "9/3/2019", "9/8/2019", "9/13/2019", "9/18/2019", "9/23/2019", "9/28/2019"]
values = [0.281380591, 0.287602726, 0.299299509, 0.31441601, 0.331162388, 0.348809159, 0.366891929, 0.384946305,
          0.40245252, 0.418669328, 0.43280011, 0.44404825, 0.451617129, 0.45471013, 0.452530635, 0.444282026,
          0.429602879, 0.409872548, 0.386774254, 0.36146592, 0.334974142, 0.308250355, 0.281945353, 0.256634769,
          0.232894234, 0.211299383, 0.192425846, 0.17669418, 0.163904626, 0.153702351, 0.145732521, 0.139640299,
          0.135070852, 0.131669344, 0.129080942, 0.12695081, 0.125007236, 0.123310994, 0.122005983]
# Convert dates to days since the first date
date_format = "%m/%d/%Y"
days_since_start = [(datetime.strptime(date, date_format) - datetime.strptime(dates[0], date_format)).days for date in dates]

# Calculate the seven phenology-related metrics
base = (min(values[:len(values) // 2]) + min(values[len(values) // 2:])) / 2
maximum = max(values)
amplitude = maximum - base
left_derivative = (values[len(values) // 5] - values[4 * len(values) // 5]) / (days_since_start[4 * len(values) // 5] - days_since_start[len(values) // 5])
right_derivative = abs((values[4 * len(values) // 5] - values[len(values) // 5]) / (days_since_start[4 * len(values) // 5] - days_since_start[len(values) // 5]))
large_integral = np.trapz(values, dx=1)
small_integral = np.trapz([base] * len(values), dx=1)

# Calculate additional parameters
start_of_season = None  # User-defined level to be calculated
end_of_season = None    # User-defined level to be calculated

# Find the nearest values in the list
left_edge_80_percent = min(values, key=lambda x: abs(x - (base + 0.8 * amplitude)))
right_edge_80_percent = min(values, key=lambda x: abs(x - (maximum - 0.8 * amplitude)))

# Calculate the middle and length of the season
middle_of_season = (days_since_start[values.index(left_edge_80_percent)] + days_since_start[values.index(right_edge_80_percent)]) / 2
length_of_season = days_since_start[values.index(right_edge_80_percent)] - days_since_start[values.index(left_edge_80_percent)]

# Print the calculated metrics
print("Base:", base)
print("Maximum:", maximum)
print("Amplitude:", amplitude)
print("Left Derivative:", left_derivative)
print("Right Derivative:", right_derivative)
print("Large Integral:", large_integral)
print("Small Integral:", small_integral)
print("Start of the Season:", start_of_season)
print("End of the Season:", end_of_season)
print("Middle of the Season:", middle_of_season)
print("Length of the Season:", length_of_season)

# Create a plot highlighting the parameters
# (Rest of the code remains the same)

# Calculate days since the first date for each date in the list
date_values = [datetime.strptime(date, date_format) for date in dates]
days_since_start_list = [(date - date_values[0]).days for date in date_values]

# Find the nearest date to middle_of_season
middle_date = min(date_values, key=lambda date: abs((date - date_values[0]).days - middle_of_season))

# Create a plot highlighting the parameters
plt.figure(figsize=(10, 6))
plt.plot(dates, values, label="NDVI", marker='o', color='blue')
plt.axhline(y=base, color='red', linestyle='--', label="Base")
plt.axhline(y=maximum, color='green', linestyle='--', label="Maximum")
plt.fill_between(dates, base, values, where=[False if v < base else True for v in values], alpha=0.2, color='purple', label="Amplitude Area")

# Highlight the parameters
plt.axvline(x=dates[values.index(left_edge_80_percent)], color='orange', linestyle='--', label="Start of the Season")
plt.axvline(x=dates[values.index(right_edge_80_percent)], color='brown', linestyle='--', label="End of the Season")
plt.axvline(x=middle_date.strftime(date_format), color='magenta', linestyle='--', label="Middle of the Season")

# Annotate the parameters
plt.annotate("Start of the Season", xy=(dates[values.index(left_edge_80_percent)], left_edge_80_percent), xytext=(20, 20),
             textcoords='offset points', arrowprops=dict(arrowstyle="->"))
plt.annotate("End of the Season", xy=(dates[values.index(right_edge_80_percent)], right_edge_80_percent), xytext=(20, -20),
             textcoords='offset points', arrowprops=dict(arrowstyle="->"))
# plt.annotate("Middle of the Season", xy=(middle_date.strftime(date_format), values[dates.index(middle_date)]), xytext=(20, 20),
#              textcoords='offset points', arrowprops=dict(arrowstyle="->"))

plt.xlabel("Date")
plt.ylabel("NDVI")
plt.title("NDVI Time Series with Phenology Metrics")
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# Base: 0.201693287
# Maximum: 0.45471013
# Amplitude: 0.253016843
# Left Derivative: 0.0020442167166666667
# Right Derivative: 0.0020442167166666667
# Large Integral: 10.992835279
# Small Integral: 7.664344906000002
# Start of the Season: None
# End of the Season: None
# Middle of the Season: 77.5
# Length of the Season: 75

# %% [markdown]
# #good for calculating SOS and EOS

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data points as arrays (same as in the previous example)
dates = ["3/22/2019", "3/27/2019", "4/1/2019", "4/6/2019", "4/11/2019", "4/16/2019", "4/21/2019", "4/26/2019",
         "5/1/2019", "5/6/2019", "5/11/2019", "5/16/2019", "5/21/2019", "5/26/2019", "5/31/2019", "6/5/2019",
         "6/10/2019", "6/15/2019", "6/20/2019", "6/25/2019", "6/30/2019", "7/5/2019", "7/10/2019", "7/15/2019",
         "7/20/2019", "7/25/2019", "7/30/2019", "8/4/2019", "8/9/2019", "8/14/2019", "8/19/2019", "8/24/2019",
         "8/29/2019", "9/3/2019", "9/8/2019", "9/13/2019", "9/18/2019", "9/23/2019", "9/28/2019"]
values = [0.281380591, 0.287602726, 0.299299509, 0.31441601, 0.331162388, 0.348809159, 0.366891929, 0.384946305,
          0.40245252, 0.418669328, 0.43280011, 0.44404825, 0.451617129, 0.45471013, 0.452530635, 0.444282026,
          0.429602879, 0.409872548, 0.386774254, 0.36146592, 0.334974142, 0.308250355, 0.281945353, 0.256634769,
          0.232894234, 0.211299383, 0.192425846, 0.17669418, 0.163904626, 0.153702351, 0.145732521, 0.139640299,
          0.135070852, 0.131669344, 0.129080942, 0.12695081, 0.125007236, 0.123310994, 0.122005983]

# Calculate the total area under the curve
total_area = np.trapz(values, dx=1)

#################################################
#################################################
# base = (min(values[:len(values) // 2]) + min(values[len(values) // 2:])) / 2
# total_area = np.trapz([base] * len(values), dx=1)
#################################################

# Calculate the target areas (5% and 95% of the total area)
target_area_5_percent = 0.05 * total_area
target_area_95_percent = 0.95 * total_area

# Initialize variables to keep track of accumulated area
accumulated_area = 0
beginning_point = None
ending_point = None

# Iterate through the data points to find the desired points
for i in range(len(dates)):
    accumulated_area += values[i]
    if accumulated_area >= target_area_5_percent and beginning_point is None:
        beginning_point = (dates[i], values[i])
    if accumulated_area >= target_area_95_percent:
        ending_point = (dates[i], values[i])
        break

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

####
# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

########$

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

#######
# Annotate the duration of the season and SOS, EOS


# Add a horizontal line to highlight the seasonal duration
ax.hlines(y=min(values), xmin=beginning_point[0], xmax=ending_point[0], color='green', linestyle='--', label='Season Duration')
#############$
# Set labels and title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title("Curve with Highlighted Points")

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Add a legend
ax.legend()
plt.grid()
# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #Pruebas

# %%
#pruevas

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# Define the data points as arrays (same as in the previous example)
dates = ["3/22/2019", "3/27/2019", "4/1/2019", "4/6/2019", "4/11/2019", "4/16/2019", "4/21/2019", "4/26/2019",
         "5/1/2019", "5/6/2019", "5/11/2019", "5/16/2019", "5/21/2019", "5/26/2019", "5/31/2019", "6/5/2019",
         "6/10/2019", "6/15/2019", "6/20/2019", "6/25/2019", "6/30/2019", "7/5/2019", "7/10/2019", "7/15/2019",
         "7/20/2019", "7/25/2019", "7/30/2019", "8/4/2019", "8/9/2019", "8/14/2019", "8/19/2019", "8/24/2019",
         "8/29/2019", "9/3/2019", "9/8/2019", "9/13/2019", "9/18/2019", "9/23/2019", "9/28/2019"]
values = [0.281380591, 0.287602726, 0.299299509, 0.31441601, 0.331162388, 0.348809159, 0.366891929, 0.384946305,
          0.402452520, 0.418669328, 0.432800110, 0.444048250, 0.451617129, 0.454710130, 0.452530635, 0.444282026,
          0.429602879, 0.409872548, 0.386774254, 0.361465920, 0.334974142, 0.308250355, 0.281945353, 0.256634769,
          0.232894234, 0.211299383, 0.192425846, 0.176694180, 0.163904626, 0.153702351, 0.145732521, 0.139640299,
          0.135070852, 0.131669344, 0.129080942, 0.126950810, 0.125007236, 0.123310994, 0.122005983]

# Calculate the total area under the curve
total_area = np.trapz(values, dx=1)

# Calculate the target areas (5% and 95% of the total area)
target_area_5_percent = 0.05 * total_area
target_area_95_percent = 0.95 * total_area

# Initialize variables to keep track of accumulated area
accumulated_area = 0
beginning_point = None
ending_point = None

# Iterate through the data points to find the desired points
for i in range(len(dates)):
    accumulated_area += values[i]
    if accumulated_area >= target_area_5_percent and beginning_point is None:
        beginning_point = (datetime.strptime(dates[i], "%m/%d/%Y"), values[i])
    if accumulated_area >= target_area_95_percent:
        ending_point = (datetime.strptime(dates[i], "%m/%d/%Y"), values[i])
        break

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

# Set labels and title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title("Curve with Highlighted Points")

# Add a text annotation for the seasonal duration
season_duration = (ending_point[0] - beginning_point[0]).days
duration_text = f'Season Duration: {season_duration} days'
ax.annotate(duration_text, xy=(beginning_point[0], beginning_point[1]), xytext=(15, 0),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"), color='green')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Add a legend
ax.legend()
plt.grid()

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1731         try:
# -> 1732             ret = self.converter.convert(x, self.units, self)
#    1733         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in convert(value, unit, axis)
#      56         # force an update so it also does type checking
# ---> 57         unit.update(values)
#      58         return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in update(self, data)
#     215             # OrderedDict just iterates over unique values in data.
# --> 216             _api.check_isinstance((str, bytes), value=val)
#     217             if convertible:
#
# ...

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

# Set labels and title, including the season duration in the title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title(f"Curve with Highlighted Points\nSeason Duration: {season_duration} days")

# Annotate the duration of the season and SOS, EOS
ax.annotate(f"SOS: {beginning_point[0].strftime('%m/%d/%Y')}", xy=(beginning_point[0], beginning_point[1]), xytext=(-30, 30),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"EOS: {ending_point[0].strftime('%m/%d/%Y')}", xy=(ending_point[0], ending_point[1]), xytext=(-30, -50),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"Duration: {season_duration} days", xy=(beginning_point[0] + (ending_point[0] - beginning_point[0]) / 2, max(values)),
            xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

# Add a horizontal line to highlight the seasonal duration
ax.hlines(y=min(values), xmin=beginning_point[0], xmax=ending_point[0], color='green', linestyle='--', label='Season Duration')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
ax.legend()
plt.grid()

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b75903fd8052> in <cell line: 20>()
#      18
#      19 # Annotate the duration of the season and SOS, EOS
# ---> 20 ax.annotate(f"SOS: {beginning_point[0].strftime('%m/%d/%Y')}", xy=(beginning_point[0], beginning_point[1]), xytext=(-30, 30),
#      21             textcoords='offset points', arrowprops=dict(arrowstyle="->"))
#      22 ax.annotate(f"EOS: {ending_point[0].strftime('%m/%d/%Y')}", xy=(ending_point[0], ending_point[1]), xytext=(-30, -50),
#
# AttributeError: 'str' object has no attribute 'strftime'

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# Define the data points as arrays (same as in the previous example)
# (Your data points definition remains the same)

# Convert the date strings to datetime objects
dates = [datetime.strptime(date, "%m/%d/%Y") for date in dates]

# Calculate the total area under the curve
total_area = np.trapz(values, dx=1)

# Calculate the target areas (5% and 95% of the total area)
target_area_5_percent = 0.05 * total_area
target_area_95_percent = 0.95 * total_area

# Initialize variables to keep track of accumulated area and season duration
accumulated_area = 0
beginning_point = None
ending_point = None

# Iterate through the data points to find the desired points
for i in range(len(dates)):
    accumulated_area += values[i]
    if accumulated_area >= target_area_5_percent and beginning_point is None:
        beginning_point = (dates[i], values[i])
    if accumulated_area >= target_area_95_percent:
        ending_point = (dates[i], values[i])
        break

# Calculate the duration of the season
season_duration = (ending_point[0] - beginning_point[0]).days

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

# Set labels and title, including the season duration in the title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title(f"Curve with Highlighted Points\nSeason Duration: {season_duration} days")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
ax.legend()
plt.grid()
# Display the plot
plt.tight_layout()
plt.show()

# %%
# Convert the date strings to datetime objects
dates = [datetime.strptime(date, "%m/%d/%Y") for date in dates]

# Calculate the total area under the curve
total_area = np.trapz(values, dx=1)

# Calculate the target areas (5% and 95% of the total area)
target_area_5_percent = 0.05 * total_area
target_area_95_percent = 0.95 * total_area

# Initialize variables to keep track of accumulated area and season duration
accumulated_area = 0
beginning_point = None
ending_point = None

# Iterate through the data points to find the desired points
for i in range(len(dates)):
    accumulated_area += values[i]
    if accumulated_area >= target_area_5_percent and beginning_point is None:
        beginning_point = (dates[i], values[i])
    if accumulated_area >= target_area_95_percent:
        ending_point = (dates[i], values[i])
        break

# Calculate the duration of the season
season_duration = (ending_point[0] - beginning_point[0]).days

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

# Set labels and title, including the season duration in the title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title(f"Curve with Highlighted Points\nSeason Duration: {season_duration} days")

# Annotate the duration of the season and SOS, EOS
ax.annotate(f"SOS: {beginning_point[0].strftime('%m/%d/%Y')}", xy=(beginning_point[0], beginning_point[1]), xytext=(-30, 30),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"EOS: {ending_point[0].strftime('%m/%d/%Y')}", xy=(ending_point[0], ending_point[1]), xytext=(-30, -50),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"Duration: {season_duration} days", xy=(beginning_point[0] + (ending_point[0] - beginning_point[0]) / 2, max(values)),
            xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
ax.legend()
plt.grid()

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-9d7b2be4d58d> in <cell line: 2>()
#       1 # Convert the date strings to datetime objects
# ----> 2 dates = [datetime.strptime(date, "%m/%d/%Y") for date in dates]
#       3
#       4 # Calculate the total area under the curve
#       5 total_area = np.trapz(values, dx=1)
#
# <ipython-input-21-9d7b2be4d58d> in <listcomp>(.0)
#       1 # Convert the date strings to datetime objects
# ----> 2 dates = [datetime.strptime(date, "%m/%d/%Y") for date in dates]
#       3
#       4 # Calculate the total area under the curve
#       5 total_area = np.trapz(values, dx=1)
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

# Set labels and title, including the season duration in the title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title(f"Curve with Highlighted Points\nSeason Duration: {season_duration} days")

# Annotate the duration of the season and SOS, EOS
ax.annotate(f"SOS: {beginning_point[0].strftime('%m/%d/%Y')}", xy=(beginning_point[0], beginning_point[1]), xytext=(-30, 30),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"EOS: {ending_point[0].strftime('%m/%d/%Y')}", xy=(ending_point[0], ending_point[1]), xytext=(-30, -50),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"Duration: {season_duration} days", xy=(beginning_point[0] + (ending_point[0] - beginning_point[0]) / 2, max(values)),
            xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

# Add a horizontal line on the x-axis to indicate the seasonal duration
ax.axvline(x=beginning_point[0], color='green', linestyle='--', label='Season Duration')
ax.axvline(x=ending_point[0], color='green', linestyle='--')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
ax.legend()
plt.grid()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Plot the curve
ax.scatter(dates, values, label="Curve")

# Highlight the area under the curve
ax.fill_between(dates, 0, values, where=[True] * len(dates), color='gray', alpha=0.2, label="Area under the curve")

# Highlight the beginning and ending points
ax.scatter(beginning_point[0], beginning_point[1], color='red', label="Beginning Point (5% of area)")
ax.scatter(ending_point[0], ending_point[1], color='blue', label="Ending Point (95% of area)")

# Set labels and title, including the season duration in the title
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title(f"Curve with Highlighted Points\nSeason Duration: {season_duration} days")

# Annotate the duration of the season and SOS, EOS
ax.annotate(f"SOS: {beginning_point[0].strftime('%m/%d/%Y')}", xy=(beginning_point[0], beginning_point[1]), xytext=(-30, 30),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"EOS: {ending_point[0].strftime('%m/%d/%Y')}", xy=(ending_point[0], ending_point[1]), xytext=(-30, -50),
            textcoords='offset points', arrowprops=dict(arrowstyle="->"))
ax.annotate(f"Duration: {season_duration} days", xy=(beginning_point[0] + (ending_point[0] - beginning_point[0]) / 2, max(values)),
            xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

# Add a horizontal line to highlight the seasonal duration
ax.hlines(y=min(values), xmin=beginning_point[0], xmax=ending_point[0], color='green', linestyle='--', label='Season Duration')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
ax.legend()
plt.grid()

# Display the plot
plt.tight_layout()
plt.show()
